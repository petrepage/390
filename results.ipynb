# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("values.csv")

# %%
df=df.sort_values(by="score",ascending=False)

# %%
df
# Out:
#        partner  egl_15  score
# 28      Q8T3E5  egl_15   9078
# 26      Q19128  egl_15   9078
# 35      B5BM28  egl_15   8869
# 34      B5BM27  egl_15   8869
# 33  A0A0K3AX35  egl_15   8869
# 36      P24348  egl_15   8869
# 6   A0A0K3AWC2  egl_15   8786
# 44      G5EGJ3  egl_15   8204
# 38      G5EC69  egl_15   8204
# 39      G5ECI6  egl_15   8204
# 40      G5EEM4  egl_15   8204
# 41      G5EFE8  egl_15   8204
# 43      G5EGI0  egl_15   8204
# 42      G5EG42  egl_15   8204
# 45      G5EGM6  egl_15   8204
# 27      Q8MQ86  egl_15   8174
# 13  A0A0K3ASN4  egl_15   7980
# 17  A0A0K3AVH5  egl_15   7980
# 19  A0A0K3AVI4  egl_15   7980
# 21  A0A0K3AYI1  egl_15   7980
# 22      D0VWL7  egl_15   7980
# 15  A0A0K3AT80  egl_15   7980
# 37      F5GU90  egl_15   7388
# 5   A0A0K3AVM4  egl_15   7260
# 2   A0A0K3ATB0  egl_15   7260
# 3   A0A0K3ATB5  egl_15   7260
# 32      G5EFM9  egl_15   7260
# 4   A0A0K3AVM0  egl_15   7260
# 25      O76385  egl_15   7260
# 7   A0A0K3AWC6  egl_15   7260
# ...
